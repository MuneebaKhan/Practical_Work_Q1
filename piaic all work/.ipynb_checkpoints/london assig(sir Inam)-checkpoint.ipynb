# %%
import pandas as pd
import os

# %%
variable = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\dataset\london.csv', parse_dates = ['timestamp'])

# %%
variable
#cnt = count
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# 5     2015-01-04 05:00:00    46  2.0  2.0   93.0         4.0           1.0
# 6     2015-01-04 06:00:00    51  1.0 -1.0  100.0         7.0           4.0
# 7     2015-01-04 07:00:00    75  1.0 -1.0  100.0         7.0           4.0
# 8     2015-01-04 08:00:00   131  1.5 -1.0   96.5         8.0           4.0
# 9     2015-01-04 09:00:00   301  2.0 -0.5  100.0         9.0           3.0
# 10    2015-01-04 10:00:00   528  3.0 -0.5   93.0        12.0           3.0
# ...

# %%
variable.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
variable.describe()
# Out:
#                 cnt            t1            t2           hum    wind_speed  \
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean    1143.101642     12.468091     11.520836     72.324954     15.913063
# std     1085.108068      5.571818      6.615145     14.313186      7.894570
# min        0.000000     -1.500000     -6.000000     20.500000      0.000000
# 25%      257.000000      8.000000      6.000000     63.000000     10.000000
# 50%      844.000000     12.500000     12.500000     74.500000     15.000000
# 75%     1671.750000     16.000000     16.000000     83.000000     20.500000
# max     7860.000000     34.000000     34.000000    100.000000     56.500000
#
#        weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000
# mean       2.722752      0.022051      0.285403      1.492075
# std        2.341163      0.146854      0.451619      1.118911
# ...

# %%
variable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
# timestamp       17414 non-null datetime64[ns]
# cnt             17414 non-null int64
# t1              17414 non-null float64
# t2              17414 non-null float64
# hum             17414 non-null float64
# wind_speed      17414 non-null float64
# weather_code    17414 non-null float64
# is_holiday      17414 non-null float64
# is_weekend      17414 non-null float64
# season          17414 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
variable.is_holiday.hist()

# %%
variable.season.hist()

# %%
variable.corr()
# Out:
#                    cnt        t1        t2       hum  wind_speed  \
# cnt           1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# hum          -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
#
#               weather_code  is_holiday  is_weekend    season
# cnt              -0.166633   -0.051698   -0.096499 -0.116180
# t1               -0.097114   -0.042233   -0.005342 -0.285851
# t2               -0.098385   -0.040051   -0.008510 -0.285900
# hum               0.334750    0.032068    0.028098  0.290381
# ...

# %%
#bar chart

# %%
#line chart

# %%
variable.plot(x = 'timestamp', y = 'cnt' ,kind = 'line')

# %%
variable[:500].plot (x = 'timestamp', y = 'cnt' ,kind = 'line')

# %%
one_pm_shares = variable[variable.timestamp.dt.hour == 1]
two_pm_shares = variable[variable.timestamp.dt.hour == 2]

# %%
print(one_pm_shares.cnt.sum())
print(two_pm_shares.cnt.sum())
# Out:
# 145257
# 98275

# %%
all_shares_per_hour = []
for hour in range(0,24):
    all_shares_Per_hour.append(variable.timestamp.dt.hour == hour)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-8996eecf2a7d> in <module>
#       1 all_shares_per_hour = []
#       2 for hour in range(0,24):
# ----> 3     all_shares_Per_hour.append(variable.timestamp.dt.hour == hour)
#
# NameError: name 'all_shares_Per_hour' is not defined

# %%
print(all_shares_per_hour())
