# %% [markdown]
# # Reading and Writing Data in Text Format

# %%
#Parsing function in pandas

# %%
import pandas as pd
import numpy as np

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file2.txt')
test_1
# Out:
#    emp_id emp_name  age      department  joining
# 0       1     aqsa   25              AI  9-10-19
# 1       2   fatima   20           CS&SE   8-9-18
# 2       3     zara   18  social-science   7-9-17
# 3       4    samra   15        commerce   7-9-19

# %%
test_1.describe()
# Out:
#          emp_id        age
# count  4.000000   4.000000
# mean   2.500000  19.500000
# std    1.290994   4.203173
# min    1.000000  15.000000
# 25%    1.750000  17.250000
# 50%    2.500000  19.000000
# 75%    3.250000  21.250000
# max    4.000000  25.000000

# %%
#clipboard

# %%
x = pd.read_clipboard()

# %%
x
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
x = pd.read_excel(r'C:\Users\Dell\.ipynb_checkpoints\excel.XLSX ')

# %%
x
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
z = pd.read_html(r'C:\Users\Dell\.ipynb_checkpoints\first.html ')

# %%
z
# Out:
# [     Name  Age
#  0    Inam   42
#  1  fayyas   22,           Shop      Address
#  0  Ali mobiles        Sadar
#  1        Chase  Bahadurabad]

# %%
z[0]
# Out:
#      Name  Age
# 0    Inam   42
# 1  fayyas   22

# %%
z[1]
# Out:
#           Shop      Address
# 0  Ali mobiles        Sadar
# 1        Chase  Bahadurabad

# %%
z[0].describe()
# Out:
#              Age
# count   2.000000
# mean   32.000000
# std    14.142136
# min    22.000000
# 25%    27.000000
# 50%    32.000000
# 75%    37.000000
# max    42.000000

# %%
z[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
# Name    2 non-null object
# Age     2 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 112.0+ bytes

# %%
#read_pickle(dataserialization concept)

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file1.txt')
test_1
# Out:
#         0    1       2        3       4
# 0    name  age  f.name  address   phone
# 1    asad   20    khan     abcd  123456
# 2  fayyaz   20  farooq     abcd   23445

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file1.txt', header=None)
test_1
# Out:
#         0    1       2        3       4
# 0    name  age  f.name  address   phone
# 1    asad   20    khan     abcd  123456
# 2  fayyaz   20  farooq     abcd   23445

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file1.txt', header=None , names=['name', 'age', 'f.name', 'address', 'phone'] ,index_col='phone')
test_1
# Out:
#           name  age  f.name  address
# phone
# phone     name  age  f.name  address
# 123456    asad   20    khan     abcd
# 23445   fayyaz   20  farooq     abcd

# %%
#check missing value
pd.isnull(test_1)
# Out:
#          name    age  f.name  address
# phone
# phone   False  False   False    False
# 123456  False  False   False    False
# 23445   False  False   False    False

# %%
#Regular Expression
#Jis ke through string pas kar raha hota
#or verify kar raha hota hai

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file2.txt', na_values = {'age':['*'],'department':['-']})
test_1
# Out:
#    emp_id emp_name   age department  joining_day  joining_month
# 0       1     aqsa  25.0         AI            9              4
# 1       2   fatima  20.0        NaN            8             19
# 2       3     zara  18.0        NaN            9              6
# 3       4    samra   NaN        NaN            4              4

# %%
import datetime

# %%
test_1 = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\file2.txt', parse_dates = [['joining_month','joining_day']])
test_1
# Out:
#   joining_month_joining_day  emp_id emp_name age department
# 0                      04 9       1     aqsa  25         AI
# 1                      19 8       2   fatima  20          -
# 2                     06 09       3     zara  18          -
# 3                     04 04       4    samra   *        NaN

# %%
variable = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\dataset\train.csv')
variable
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
chunker = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\dataset\train.csv', chunksize=200)

# %%
chunker

# %%
for rec in chunker:
    print(rec)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
obj = {"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": 'null',
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
 {"name": "Katie", "age": 38,
 "pets": ["Sixes", "Stache", "Cisco"]}]
}

# %%
obj
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': 'null',
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
siblings = pd.DataFrame(obj['siblings'], columns=['name', 'age'])

# %%
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
x.to_pickle('data2.bin')

# %%
x
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29381',
#   'id': 516783350,
#   'node_id': 'MDU6SXNzdWU1MTY3ODMzNTA=',
#   'number': 29381,
#   'title': 'MemoryError when using `.drop_duplicates()`',
#   'user': {'login': 'Mikerah',
#    'id': 4249799,
#    'node_id': 'MDQ6VXNlcjQyNDk3OTk=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/4249799?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mikerah',
#    'html_url': 'https://github.com/Mikerah',
#    'followers_url': 'https://api.github.com/users/Mikerah/followers',
# ...

# %%
import sqlite3

# %%
query = """ CREATE TABLE test(a VARCHAR(20), b VARCHAR(20),c REAL, d INTEGER );"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
 ('Tallahassee', 'Florida', 2.6, 3),
 ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('select * from test')

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]
