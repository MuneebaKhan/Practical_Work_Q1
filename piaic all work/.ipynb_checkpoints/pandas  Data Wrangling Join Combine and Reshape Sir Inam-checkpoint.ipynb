# %% [raw]
# group by method learning karni hai lazmi..(Group by ap ke particualr frame work utha kar la rha hai)

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\dataset\New folder\summer.csv')
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df = pd.DataFrame(data)

# %%
a = df.groupby(['Sport','City','Medal'])

# %%
a.groups
# Out:
# {('Aquatics',
#   'Amsterdam',
#   'Bronze'): Int64Index([5004, 5007, 5010, 5013, 5016, 5019, 5022, 5025, 5028, 5031, 5034,
#              5037, 5040, 5043, 5044, 5045, 5046, 5055, 5056, 5057, 5058, 5067,
#              5068, 5069, 5070, 5071, 5072, 5073, 5074, 5075],
#             dtype='int64'),
#  ('Aquatics',
#   'Amsterdam',
#   'Gold'): Int64Index([5005, 5008, 5011, 5014, 5017, 5020, 5023, 5026, 5029, 5032, 5035,
#              5038, 5041, 5047, 5048, 5049, 5050, 5059, 5060, 5061, 5062, 5076,
#              5077, 5078, 5079, 5080, 5081, 5082, 5083],
#             dtype='int64'),
#  ('Aquatics',
#   'Amsterdam',
#   'Silver'): Int64Index([5006, 5009, 5012, 5015, 5018, 5021, 5024, 5027, 5030, 5033, 5036,
#              5039, 5042, 5051, 5052, 5053, 5054, 5063, 5064, 5065, 5066, 5084,
#              5085, 5086, 5087, 5088, 5089, 5090],
#             dtype='int64'),
#  ('Aquatics',
#   'Antwerp',
# ...

# %% [markdown]
# # Reshaping and pivoting

# %% [markdown]
# # Reshaping with Hierarchical Indexing

# %% [raw]
# Stack column to row
# unstack row to column

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Dell\.ipynb_checkpoints\dataset\stack-unstack.csv')
data
# Out:
#   Students class  grade
# 0   Muniba    ai      2
# 1   Fatima    ai      1

# %%
r = data.stack()
r
# Out:
# 0  Students    Muniba
#    class           ai
#    grade            2
# 1  Students    Fatima
#    class           ai
#    grade            1
# dtype: object

# %%
e = data.unstack()
e
# Out:
# Students  0    Muniba
#           1    Fatima
# class     0        ai
#           1        ai
# grade     0         2
#           1         1
# dtype: object

# %%
r.unstack(0)
# Out:
#                0       1
# Students  Muniba  Fatima
# class         ai      ai
# grade          2       1

# %%
r.unstack(1)
# Out:
#   Students class grade
# 0   Muniba    ai     2
# 1   Fatima    ai     1

# %%
s1 = pd.Series([0, 1, 2, 3], index=['a', 'b', 'c', 'd'])
s2 = pd.Series([4, 5, 6], index=['c', 'd', 'e'])
data2 = pd.concat([s1, s2], keys=['one', 'two'])
data2
# Out:
# one  a    0
#      b    1
#      c    2
#      d    3
# two  c    4
#      d    5
#      e    6
# dtype: int64

# %%
#unstack stack pr ja sakta hai but unstack pr nhi kia jaskata
d = data2.unstack().stack()

# %%
d
# Out:
# one  a    0.0
#      b    1.0
#      c    2.0
#      d    3.0
# two  c    4.0
#      d    5.0
#      e    6.0
# dtype: float64

# %% [markdown]
# # Pivoting “Long” to “Wide” Format
